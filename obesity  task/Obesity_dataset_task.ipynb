# %% [markdown]
# ## Part 1: Data Loading and Inspection
# Task:
# Loading the Obesity Dataset from Kaggle into a DataFrame using pandas.
# and other import functions needed

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
import scipy.stats as stats
import scipy.stats as Pearsonr
import scipy.stats as spearmanr
import statsmodels.api as sm
from scipy import stats 
sns.set()

# %% [markdown]
# - Imported all necessary libraries neded to carry out this analysis

# %%
classwork=pd.read_excel('Obesity_dataset_task.xlsx')
classwork
# Out:
#       Sex  Age  Height  Overweight_Obese_Family  Consumption_of_Fast_Food  \
# 0       2   18     155                        2                         2
# 1       2   18     158                        2                         2
# 2       2   18     159                        2                         2
# 3       2   18     162                        2                         2
# 4       2   18     165                        2                         1
# ...   ...  ...     ...                      ...                       ...
# 1605    2   51     165                        2                         1
# 1606    2   51     163                        2                         1
# 1607    2   52     162                        1                         2
# 1608    2   53     168                        2                         1
# 1609    2   54     170                        1                         1
#
#       Frequency_of_Consuming_Vegetables  Number_of_Main_Meals_Daily  \
# ...

# %% [markdown]
# - loaded the data set into the dataframe

# %% [markdown]
# ## -	Inspect the structure of the data:
# -	How many rows and columns are in the dataset?

# %%
classwork.shape
# Out:
# (1610, 15)

# %% [markdown]
# - there are a total of 15 columns on the data frame and 1609 rows

# %% [markdown]
# - WHAT ARE THE DATA TYPES OF THE COLUMN

# %%
 classwork.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Sex                                1610 non-null   int64
#  1   Age                                1610 non-null   int64
#  2   Height                             1610 non-null   int64
#  3   Overweight_Obese_Family            1610 non-null   int64
#  4   Consumption_of_Fast_Food           1610 non-null   int64
#  5   Frequency_of_Consuming_Vegetables  1610 non-null   int64
#  6   Number_of_Main_Meals_Daily         1610 non-null   int64
#  7   Food_Intake_Between_Meals          1610 non-null   int64
#  8   Smoking                            1610 non-null   int64
#  9   Liquid_Intake_Daily                1610 non-null   int64
#  10  Calculation_of_Calorie_Intake      1610 non-null   int64
# ...

# %%
classwork.describe()
# Out:
#                Sex          Age       Height  Overweight_Obese_Family  \
# count  1610.000000  1610.000000  1610.000000              1610.000000
# mean      1.557764    33.115528   167.741615                 1.834783
# std       0.496806     9.835076     7.979873                 0.371492
# min       1.000000    18.000000   150.000000                 1.000000
# 25%       1.000000    25.000000   161.000000                 2.000000
# 50%       2.000000    32.000000   168.000000                 2.000000
# 75%       2.000000    41.000000   174.000000                 2.000000
# max       2.000000    54.000000   193.000000                 2.000000
#
#        Consumption_of_Fast_Food  Frequency_of_Consuming_Vegetables  \
# count               1610.000000                        1610.000000
# mean                   1.729193                           2.063354
# std                    0.444515                           0.746043
# ...

# %% [markdown]
# - the type for all columns are all numerical(integer)

# %%
classwork.head()
# Out:
#    Sex  Age  Height  Overweight_Obese_Family  Consumption_of_Fast_Food  \
# 0    2   18     155                        2                         2
# 1    2   18     158                        2                         2
# 2    2   18     159                        2                         2
# 3    2   18     162                        2                         2
# 4    2   18     165                        2                         1
#
#    Frequency_of_Consuming_Vegetables  Number_of_Main_Meals_Daily  \
# 0                                  3                           1
# 1                                  3                           1
# 2                                  2                           1
# 3                                  2                           2
# 4                                  2                           1
#
#    Food_Intake_Between_Meals  Smoking  Liquid_Intake_Daily  \
# 0                          3        2                    1
# ...

# %%
classwork.isna().sum()
# Out:
# Sex                                  0
# Age                                  0
# Height                               0
# Overweight_Obese_Family              0
# Consumption_of_Fast_Food             0
# Frequency_of_Consuming_Vegetables    0
# Number_of_Main_Meals_Daily           0
# Food_Intake_Between_Meals            0
# Smoking                              0
# Liquid_Intake_Daily                  0
# Calculation_of_Calorie_Intake        0
# Physical_Excercise                   0
# Schedule_Dedicated_to_Technology     0
# Type_of_Transportation_Used          0
# Class                                0
# dtype: int64

# %% [markdown]
# ## Part 2: Data Cleaning (if necessary)
# Task:
# Handle missing values (if any were found in Part 1):
#
#
# -	If there are missing values, decide whether to remove them or fill them with some statistical value (e.g., mean, median).
# -	Check for duplicate rows and remove them if necessary.
# -	Ensure all numeric columns are in the correct data type for further analysis.

# %% [markdown]
# - there are no missing value so there is no neeed to fill mmissing values, and no duplicate rows; all numeric columns are in correct data txpe for analysis

# %% [markdown]
# ## Part 3: Data Visualization
# Task:
# -	Visualize the distribution of Age in the dataset using a histogram.

# %%
sns.histplot(classwork['Age'], bins=10, kde=True, color='orange')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The Ages of 21-25 have the highest distribution; they where the age bracket involved the most in the data survey

# %% [markdown]
# ## -- Create box plots for variables like Height and Age to explore their distributions and potential outliers.

# %%
sns.boxplot(x='Age', y='Height', data=classwork, palette= "Set2")
plt.title('Box Plot for distibution and potential outliers analysing Age and Height')
plt.xticks(fontsize=8) 
plt.yticks(fontsize=5)
plt.show()
# Out:
# C:\Users\Claudia\AppData\Local\Temp\ipykernel_21340\3685335275.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Age', y='Height', data=classwork, palette= "Set2")

# %% [markdown]
# ## Use scatterplots to visualize the relationships between Age and other variables such as height, physical exercise, Number_of_main_meals_daily, frequency_of_consuming_vegetables.

# %%
columns_of_interests = ['Age', 'Height', 'Physical_Excercise', 'Number_of_Main_Meals_Daily', 'Frequency_of_Consuming_Vegetables']
for column in columns_of_interests:
    sns.scatterplot(x=column, y= 'Age', data = classwork)
    plt.title(f'Age vs {'Age', 'Height', 'Physical_Excercise', 'Number_of_Main_Meals_Daily', 'Frequency_of_Consuming_Vegetables'}')
    plt.show()

# %% [markdown]
# ## - the scatter plot did not seem to give a reasonable and understandable visualisation owing to the volume of data set we are working with,
#  I summise that a Scatter plot is not the right visualization tool for this dataset type,
#  and i would suggest a pie chart as a suitable visualisation tool, which i would display below.

# %%
columns_of_interest = ['Physical_Excercise', 'Number_of_Main_Meals_Daily', 'Frequency_of_Consuming_Vegetables', 'Liquid_Intake_Daily', 'Schedule_Dedicated_to_Technology']  # Replace with your actual column names

sns.set_style("darkgrid")


num_charts = len(columns_of_interest)
fig, axs = plt.subplots(1, num_charts, figsize=(15, 5))  


for i, column in enumerate(columns_of_interest):
   
    counts = classwork[column].value_counts()
    
    wedges, texts, autotexts=axs[i].pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('colorblind'))
    plt.setp(texts, size=7)
    plt.setp(autotexts, size=7)
    axs[i].axis('equal') 
    axs[i].set_title(column, fontsize=6)

plt.tight_layout()  
plt.show()

# %% [markdown]
# ## INTERPRETATION
# The analysis shows general trends in physical exercise, meal frequency, vegetable intake, and technology use. These habits may vary by age group and
# affect health and lifestyle.
# However, the charts only show proportions and don't establish a direct connection with age or height

# %% [markdown]
# ## Part 4: Correlation Analysis

# %% [markdown]
# ## Task:
# -	Calculate the correlation matrix for the numeric variables in the dataset.

# %%
correlation_matrix = classwork.corr()
correlation_matrix
# Out:
#                                         Sex       Age    Height  \
# Sex                                1.000000 -0.182114 -0.690250
# Age                               -0.182114  1.000000  0.115491
# Height                            -0.690250  0.115491  1.000000
# Overweight_Obese_Family            0.068580 -0.161475 -0.165359
# Consumption_of_Fast_Food           0.059621 -0.272612 -0.031478
# Frequency_of_Consuming_Vegetables  0.146067 -0.394701 -0.090057
# Number_of_Main_Meals_Daily         0.044877  0.328642 -0.055054
# Food_Intake_Between_Meals         -0.011508  0.047053 -0.000186
# Smoking                            0.196608 -0.077778 -0.141490
# Liquid_Intake_Daily                0.012885  0.026510 -0.026460
# Calculation_of_Calorie_Intake     -0.027745 -0.203458 -0.029721
# Physical_Excercise                -0.086369  0.337484  0.076698
# Schedule_Dedicated_to_Technology  -0.005656 -0.254816  0.001916
# Type_of_Transportation_Used        0.028805 -0.689950 -0.003872
# ...

# %% [markdown]
# The correlation matrix reveals several key relationships:
# - **Age** shows a strong positive correlation with **Class** (0.579) and a negative correlation with **Type of Transportation** (-0.689).
# - **Vegetable Consumption** is positively correlated with **Fast Food Consumption** (0.340) but negatively with **Class** (-0.544).
# - **Physical Exercise** and **Liquid Intake Daily** show minimal correlation with other variables.

# %% [markdown]
# ## -Plot a heatmap of the correlations to visually identify the strongest relationships between variables.

# %%
plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation heatmap')
plt.show()

# %% [markdown]
# ## The visualization of the correlation using a heat map clearly shows that there is a positive correlation accross all variables
#
# where red = +ve correlation
# and light blue = -ve correlation
# and dark blue = No correlation

# %% [markdown]
# ## Part 5: Simple Linear Regression
# Task:
# -	Perform a simple linear regression to predict height using Age as the predictor.

# %%
X = classwork['Age']
Y = classwork['Height']

# %%
X = sm.add_constant(X)
linear_prediction = sm.OLS(Y,X).fit()

# %%
linear_prediction.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Height   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     21.74
# Date:                Wed, 27 Nov 2024   Prob (F-statistic):           3.38e-06
# Time:                        13:58:38   Log-Likelihood:                -5617.0
# No. Observations:                1610   AIC:                         1.124e+04
# Df Residuals:                    1608   BIC:                         1.125e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        164.6385      0.694    237.135      0.000     163.277     166.000
# ...

# %%
#Extract independent and dependent variable 
X = classwork['Age']
Y = classwork['Height']
 
beta_0 = 164.6385  #(Intercept)
beta_1 =  0.0937  #(Slope)

#generate the trendline using regression equation
y_pred = beta_0 + beta_1*X

#Plot the scatter chart
sns.scatterplot(x = X, y = Y)
plt.title ('Age vs Height')

#Add a trendline 
plt.plot(X, y_pred, color = 'purple', label = 'Trendline')


plt.xlabel('Age')
plt.ylabel('Height')
plt.show()

# %% [markdown]
# -	Interpret the regression results: What is the relationship between age and height? How much of the variance in age is explained by height?

# %% [markdown]
# The regression analysis produced an intercept value of **164.6385** and a slope of **0.0937**, indicating the model's linear relationship
# between Age and Height. The omnibus value of **87.466** and its **p-value (0.000)** suggest that the errors are not normally distributed.
# The **Durbin-Watson statistic (0.691)** points to positive autocorrelation, violating regression assumptions.
# The **Jarque-Bera statistic (41.95)** with a **p-value < 0.05** confirms residuals do not follow a normal distribution.
# A **skew value of 0.197** indicates a slight positive skew, meaning the tails lean slightly to the right. Despite this,
# the **kurtosis value of 2.315**, close to 3, suggests residuals are near-normal.
# Lastly, the condition number (**121**) indicates potential multicollinearity,
# suggesting a strong correlation between Age and Height that could impact the stability and interpretation of regression coefficients.

# %% [markdown]
# The regression shows a very weak link between **Age** and **Height**, with **height explaining only 1.3% of age's variance** (R-squared = 0.013).
# The positive slope (0.0937) suggests height slightly increases with age, but the relationship is minimal.
# While the model is statistically significant (F-statistic = 21.74, p-value < 0.0001), the low R-squared means height is not a strong predictor of age.

# %% [markdown]
# ## Part 6: Multiple Linear Regression
# Task:
# -	Perform a multiple linear regression to predict overweight_obese_family using age, height, frequency of consuming vegetable, number of main meals daily, liquid intake daily, physical exercise, and schedule dedicated to technology

# %%
L = classwork[['Age', 'Height', 'Physical_Excercise', 'Number_of_Main_Meals_Daily', 'Frequency_of_Consuming_Vegetables', 'Liquid_Intake_Daily', 'Schedule_Dedicated_to_Technology']]
M = classwork['Overweight_Obese_Family']

# %%
L = sm.add_constant(L)
multiple_linear_prediction = sm.OLS(M,L).fit()

# %%
multiple_linear_prediction.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     Overweight_Obese_Family   R-squared:                       0.108
# Model:                                 OLS   Adj. R-squared:                  0.104
# Method:                      Least Squares   F-statistic:                     27.68
# Date:                     Wed, 27 Nov 2024   Prob (F-statistic):           4.08e-36
# Time:                             13:59:01   Log-Likelihood:                -597.80
# No. Observations:                     1610   AIC:                             1212.
# Df Residuals:                         1602   BIC:                             1255.
# Df Model:                                7
# Covariance Type:                 nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
classwork['predicted_Overweight_Obese_Family'] = multiple_linear_prediction.predict(L)
classwork[['Overweight_Obese_Family', 'predicted_Overweight_Obese_Family']].head()
# Out:
#    Overweight_Obese_Family  predicted_Overweight_Obese_Family
# 0                        2                           2.056494
# 1                        2                           2.080621
# 2                        2                           2.039525
# 3                        2                           1.945515
# 4                        2                           1.909861

# %% [markdown]
# -	Interpret the regression results: Which predictors are statistically significant?

# %% [markdown]
# The multiple linear regression model to predict **Overweight_Obese_Family** shows the following insights:
#
# 1. **R-squared (0.108)** indicates that **11% of the variance** in **Overweight_Obese_Family** is explained by the
# predictors (Age, Height, Physical Exercise, etc.).
# 2. **Height**, **Physical Exercise**, **Number of Main Meals Daily**, **Frequency of Consuming Vegetables**, **Liquid Intake Daily**,
# and **Schedule Dedicated to Technology** are statistically significant predictors, with p-values < 0.05.
# 3. **Age** is not a significant predictor (p-value = 0.835).
# 4. The **Durbin-Watson value (1.978)** suggests no major autocorrelation issues.
#
# In summary, while the model explains a small portion of the variance, several factors like
# **Height**, **Physical Exercise**, and **Vegetable Consumption** are important contributors to predicting **Overweight_Obese_Family**.

# %% [markdown]
# From the regression results, to determine which predictors are statistically significant,
# you should look at the p-values for each coefficient. If a predictor’s p-value is less than 0.05, it is typically considered statistically significant.
#
# The regression results show that several predictors are statistically significant:
#
# 1. **Height** (p-value = 0.000), **Physical Exercise** (p-value = 0.001), **Number of Main Meals Daily** (p-value = 0.000),
# **Frequency of Consuming Vegetables** (p-value = 0.000), **Liquid Intake Daily** (p-value = 0.002), and
# **Schedule Dedicated to Technology** (p-value = 0.010) are all significant predictors of **Overweight_Obese_Family**.
#
# 2. **Age** (p-value = 0.835) is **not significant** in predicting **Overweight_Obese_Family**.
#
# These predictors show meaningful relationships with the outcome, except for age.

# %% [markdown]
# ### Suggestions Based on Analysis
#
# 1. **Enhance Physical Activity**: Increasing physical exercise can help in managing overweight/obesity within families.
# 2. **Promote Healthy Eating Habits**: Encouraging regular vegetable consumption and moderating meal frequency may
# contribute to healthier family lifestyles.
# 3. **Limit Technology Usage**: Reducing time spent on technology can have beneficial effects on health, supporting better weight management.
# 4. **Personalized Interventions**: Since age was not a significant predictor, a more tailored approach focusing on lifestyle factors
#     like exercise, diet, and technology usage may yield better results.
